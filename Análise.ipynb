# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from pyUFbr.baseuf import ufbr

# %%
# Carregar arquivos
df_2024 = pd.read_csv('dados/resultado_2024.csv', delimiter=',', encoding='utf-8')
df_2023 = pd.read_csv('dados/resultado_2023.csv', delimiter=',', encoding='utf-8')
df_2022 = pd.read_csv('dados/resultado_2022.csv', delimiter=',', encoding='utf-8')

# %%
dfs = [(2022, df_2022), (2023, df_2023), (2024, df_2024)]

for ano, df in dfs:

    print(f"\n\nAnalise do df: {ano}")

    print(f"\nValores Ausentes:")
    print(df.isna().sum())
    
    try: 
        df['data_inversa'] = pd.to_datetime(df['data_inversa'])
        df['horario'] = pd.to_datetime(df['horario'], format='%H:%M:%S').dt.time

        valores_anos = df['data_inversa'].dt.year.value_counts().keys()
        if list(valores_anos) == [df['data_inversa'].dt.year[0]] and len(valores_anos) == 1:
            print("\nData e horário estão certos!")
        else:
            print("\nExiste um valor do ano que não corresponde a tabela")
    except: 
        print("\nData ou horário possuem erros!")
    
    print("\nVerificação dos valores dia da semana:")
    print(sorted(df['dia_semana'].value_counts().keys()))
    
    print("\nVerificação dos valores fase do dia:")
    valores_fase_dia = sorted(df['fase_dia'].value_counts().keys())
    print(valores_fase_dia)

    for valor in valores_fase_dia:
        df_fase = df[df['fase_dia'] == valor]
        
        horarios_decimal = df_fase['horario'].apply(lambda x: x.hour + x.minute / 60.0)
        
        plt.hist(horarios_decimal, bins=24, range=(0, 24), color='skyblue', edgecolor='black', alpha=0.7)
        
        plt.xlabel('Horário (em horas)')
        plt.ylabel('Número de valores')
        plt.title(f'Distribuição de horários para a fase {valor}')
        
        plt.xticks(range(0, 25), [f"{h:02d}:00" for h in range(24)] + ["23:59"], rotation=90)
        
        plt.tight_layout()
        plt.show()

    print("\nVerificação dos valores do estado:")
    # Verifica se os estado existe
    df['estado_valido'] = df['uf'].apply(lambda sigla: sigla.upper() in ufbr.list_uf)
    
    # Verifica se existe algum valor False na coluna 'estado_valido'
    estado_invalido = not df['estado_valido'].all()
    
    if estado_invalido:
        print("Existe pelo menos 1 estado inválido.")
        print(df[['estado_valido']==False])
    else:
        print("Todos os estados são validos.")

    print("\nVerificação se existe mais pessoas feridas do que pessoas numa linha:")
    df_verificacao = df.query('pessoas < feridos')
    
    if not df_verificacao.empty:
        print("Existem casos onde o número de pessoas feridas é maior que o número de pessoas.")
        print(df_verificacao)
    else:
        print("Não há casos onde o número de pessoas feridas é maior que o número de pessoas.")


    print("\nVerificação se existe mais mortos do que pessoas numa linha:")
    df_verificacao = df.query('pessoas < mortos')
    
    if not df_verificacao.empty:
        print("Existem casos onde o número de mortos é maior que o número de pessoas.")
        print(df_verificacao[['pessoas', 'mortos']])
    else:
        print("Não há casos onde o número mortos é maior que o número de pessoas.")

    print("\nVerificação dos valores pessoas envolvidas:")
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

    # Histograma
    ax1.hist(df['pessoas'], color='skyblue', edgecolor='black', alpha=0.7)
    ax1.set_xlabel('Pessoas envolvidas')
    ax1.set_ylabel('Número de valores')
    ax1.set_title('Distribuição de pessoas envolvidas')
    
    # Boxplot
    ax2.boxplot(df['pessoas'], widths=0.5, patch_artist=True, boxprops=dict(facecolor='skyblue'))
    ax2.set_xlabel('Pessoas envolvidas')
    ax2.set_title('Boxplot de pessoas envolvidas')
    
    plt.tight_layout()
    plt.show()
    
    print("\nVerificação dos valores pessoas feridas:")
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    
    # Histograma
    ax1.hist(df['feridos'], color='skyblue', edgecolor='black', alpha=0.7)
    ax1.set_xlabel('Pessoas feridas')
    ax1.set_ylabel('Número de valores')
    ax1.set_title('Distribuição de pessoas feridas')
    
    # Boxplot
    ax2.boxplot(df['feridos'], widths=0.5, patch_artist=True, boxprops=dict(facecolor='skyblue'))
    ax2.set_xlabel('Pessoas feridas')
    ax2.set_title('Boxplot de pessoas feridas')
    
    plt.tight_layout()
    plt.show()
    
    print("\nVerificação dos valores de mortos:")
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

    # Histograma
    ax1.hist(df['mortos'], color='skyblue', edgecolor='black', alpha=0.7)
    ax1.set_xlabel('Quantidade mortos')
    ax1.set_ylabel('Número de valores')
    ax1.set_title('Distribuição de mortos')
    
    # Boxplot
    ax2.boxplot(df['mortos'], widths=0.5, patch_artist=True, boxprops=dict(facecolor='skyblue'))
    ax2.set_xlabel('Mortos')
    ax2.set_title('Boxplot de mortos')
    
    plt.tight_layout()
    plt.show()    
    
    print("\nVerificação dos valores de número de veiculos:")
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

    # Histograma
    ax1.hist(df['veiculos'], color='skyblue', edgecolor='black', alpha=0.7)
    ax1.set_xlabel('Quantidade veículos')
    ax1.set_ylabel('Número de valores')
    ax1.set_title('Distribuição de veículos')
    
    # Boxplot
    ax2.boxplot(df['veiculos'], widths=0.5, patch_artist=True, boxprops=dict(facecolor='skyblue'))
    ax2.set_xlabel('Veículos')
    ax2.set_title('Boxplot de Veículos')
    
    plt.tight_layout()
    plt.show()    

    print("\nVerificação se os valores de pessoas for 0 (nulo):")
    pessoas_nulo = df[df['pessoas'] == 0]
    if pessoas_nulo.empty:
        print("Não há valores 0 em pessoas")
    else:
        print("Há valores 0 em pessoas")

    print("\nVerificação se os valores de veículo for 0 (nulo):")
    veiculos_nulo = df[df['veiculos'] == 0]
    if veiculos_nulo.empty:
        print("Não há valores 0 em veículo")
    else:
        print("Há valores 0 em veículo")

    print("\nVerificação dos valores do sentido da via:")
    print(sorted(df['sentido_via'].value_counts().keys()))

    print("\nVerificação dos valores do tipo da pista:")
    print(sorted(df['tipo_pista'].value_counts().keys()))

    print("\nVerificação dos valores do uso do solo:")
    print(sorted(df['uso_solo'].value_counts().keys()))

    print("\nVerificação dos valores do tracado da via:")
    print(sorted(df['tracado_via'].value_counts().keys()))

    print("\nVerificação dos valores da classificação do acidente:")
    print(sorted(df['classificacao_acidente'].value_counts().keys()))

    print("\nVerificação dos valores do tipo do acidente:")
    print(sorted(df['tipo_acidente'].value_counts().keys()))

    print("\nVerificação dos valores da condição metereologica:")
    print(sorted(df['condicao_metereologica'].value_counts().keys()))

    print("\nVerificação dos valores da causa do acidente:")
    print(sorted(df['causa_acidente'].value_counts().keys()))

    print("\nVerificação dos valores do tipo do veículo:")
    print(sorted(df['tipo_veiculo'].value_counts().keys()))

    print("\nVerificação dos valores do ano de fabricação do veículo:")
    print(sorted(df['ano_fabricacao_veiculo'].value_counts().keys()))

    print("\nVerificação do número de valores do ano de fabricação do veículo iguais a 0:")
    print(sorted(df[df['ano_fabricacao_veiculo']==0]['ano_fabricacao_veiculo'].value_counts()))
# Out:
# Analise do df: 2022
#
# Valores Ausentes:
# id                           0
# tipo_veiculo                 0
# marca                     4039
# ano_fabricacao_veiculo    5120
# data_inversa                 0
# dia_semana                   0
# horario                      0
# uf                           0
# br                         199
# km                         199
# municipio                    0
# causa_acidente               0
# tipo_acidente                0
# classificacao_acidente       0
# fase_dia                     0
# sentido_via                  0
# condicao_metereologica       0
# tipo_pista                   0
# tracado_via                  0
# uso_solo                     0
# pessoas                      0
# mortos                       0
# feridos                      0
# veiculos                     0
# latitude                     0
# longitude                    0
# delegacia                   17
# estado_valido                0
# dtype: int64
#
# Data e horário estão certos!
#
# Verificação dos valores dia da semana:
# ['domingo', 'quarta-feira', 'quinta-feira', 'segunda-feira', 'sexta-feira', 'sábado', 'terça-feira']
#
# Verificação dos valores fase do dia:
# ['Amanhecer', 'Anoitecer', 'Plena Noite', 'Pleno dia']
# Verificação dos valores do estado:
# Todos os estados são validos.
#
# Verificação se existe mais pessoas feridas do que pessoas numa linha:
# Não há casos onde o número de pessoas feridas é maior que o número de pessoas.
#
# Verificação se existe mais mortos do que pessoas numa linha:
# Não há casos onde o número mortos é maior que o número de pessoas.
#
# Verificação dos valores pessoas envolvidas:
# Verificação dos valores pessoas feridas:
# Verificação dos valores de mortos:
# Verificação dos valores de número de veiculos:
# Verificação se os valores de pessoas for 0 (nulo):
# Não há valores 0 em pessoas
#
# Verificação se os valores de veículo for 0 (nulo):
# Não há valores 0 em veículo
#
# Verificação dos valores do sentido da via:
# ['Crescente', 'Decrescente', 'Não Informado']
#
# Verificação dos valores do tipo da pista:
# ['Dupla', 'Múltipla', 'Simples']
#
# Verificação dos valores do uso do solo:
# ['Não', 'Sim']
#
# Verificação dos valores do tracado da via:
# ['Aclive', 'Aclive;Curva                  ', 'Aclive;Curva;Em Obras         ', 'Aclive;Curva;Interseção de Via', 'Aclive;Curva;Retorno Regulamen', 'Aclive;Curva;Viaduto          ', 'Aclive;Desvio Temporário;Curva', 'Aclive;Em Obras               ', 'Aclive;Em Obras;Reta          ', 'Aclive;Em Obras;Reta;Interseçã', 'Aclive;Interseção de Vias     ', 'Aclive;Interseção de Vias;Curv', 'Aclive;Interseção de Vias;Reta', 'Aclive;Interseção de Vias;Reto', 'Aclive;Interseção de Vias;Rota', 'Aclive;Ponte                  ', 'Aclive;Ponte;Curva            ', 'Aclive;Ponte;Reta             ', 'Aclive;Ponte;Viaduto          ', 'Aclive;Reta                   ', 'Aclive;Reta;Em Obras          ', 'Aclive;Reta;Interseção de Vias', 'Aclive;Reta;Ponte             ', 'Aclive;Reta;Retorno Regulament', 'Aclive;Reta;Rotatória         ', 'Aclive;Reta;Viaduto           ', 'Aclive;Retorno Regulamentado  ', 'Aclive;Retorno Regulamentado;C', 'Aclive;Rotatória;Curva        ', 'Aclive;Rotatória;Reta         ', 'Aclive;Viaduto                ', 'Aclive;Viaduto;Curva          ', 'Aclive;Viaduto;Interseção de V', 'Aclive;Viaduto;Reta           ', 'Aclive;Viaduto;Retorno Regulam', 'Curva', 'Curva;Aclive                  ', 'Curva;Aclive;Em Obras         ', 'Curva;Aclive;Interseção de Via', 'Curva;Aclive;Ponte            ', 'Curva;Aclive;Retorno Regulamen', 'Curva;Aclive;Rotatória        ', 'Curva;Aclive;Viaduto          ', 'Curva;Declive                 ', 'Curva;Declive;Em Obras        ', 'Curva;Declive;Em Obras;Desvio ', 'Curva;Declive;Interseção de Vi', 'Curva;Declive;Ponte           ', 'Curva;Declive;Retorno Regulame', 'Curva;Declive;Viaduto         ', 'Curva;Desvio Temporário       ', 'Curva;Desvio Temporário;Aclive', 'Curva;Desvio Temporário;Decliv', 'Curva;Desvio Temporário;Em Obr', 'Curva;Em Obras                ', 'Curva;Em Obras;Aclive         ', 'Curva;Em Obras;Declive        ', 'Curva;Em Obras;Desvio Temporár', 'Curva;Em Obras;Interseção de V', 'Curva;Interseção de Vias      ', 'Curva;Interseção de Vias;Acliv', 'Curva;Interseção de Vias;Decli', 'Curva;Interseção de Vias;Rotat', 'Curva;Ponte                   ', 'Curva;Ponte;Declive           ', 'Curva;Retorno Regulamentado   ', 'Curva;Retorno Regulamentado;Ac', 'Curva;Retorno Regulamentado;In', 'Curva;Rotatória               ', 'Curva;Rotatória;Aclive        ', 'Curva;Rotatória;Interseção de ', 'Curva;Túnel                   ', 'Curva;Viaduto                 ', 'Curva;Viaduto;Aclive          ', 'Curva;Viaduto;Declive         ', 'Curva;Viaduto;Declive;Interseç', 'Curva;Viaduto;Interseção de Vi', 'Curva;Viaduto;Retorno Regulame', 'Declive', 'Declive;Curva                 ', 'Declive;Curva;Em Obras        ', 'Declive;Curva;Interseção de Vi', 'Declive;Curva;Ponte           ', 'Declive;Curva;Retorno Regulame', 'Declive;Curva;Viaduto         ', 'Declive;Desvio Temporário     ', 'Declive;Desvio Temporário;Em O', 'Declive;Desvio Temporário;Reta', 'Declive;Em Obras              ', 'Declive;Em Obras;Curva        ', 'Declive;Em Obras;Reta         ', 'Declive;Em Obras;Viaduto      ', 'Declive;Interseção de Vias    ', 'Declive;Interseção de Vias;Cur', 'Declive;Interseção de Vias;Ret', 'Declive;Interseção de Vias;Rot', 'Declive;Interseção de Vias;Via', 'Declive;Ponte                 ', 'Declive;Ponte;Curva           ', 'Declive;Ponte;Reta            ', 'Declive;Reta                  ', 'Declive;Reta;Em Obras         ', 'Declive;Reta;Em Obras;Interseç', 'Declive;Reta;Interseção de Via', 'Declive;Reta;Ponte            ', 'Declive;Reta;Retorno Regulamen', 'Declive;Reta;Rotatória        ', 'Declive;Reta;Viaduto          ', 'Declive;Retorno Regulamentado ', 'Declive;Retorno Regulamentado;', 'Declive;Rotatória             ', 'Declive;Rotatória;Reta        ', 'Declive;Viaduto               ', 'Declive;Viaduto;Curva         ', 'Declive;Viaduto;Em Obras;Reta ', 'Declive;Viaduto;Reta          ', 'Desvio Temporário', 'Desvio Temporário;Aclive      ', 'Desvio Temporário;Aclive;Em Ob', 'Desvio Temporário;Curva       ', 'Des ...
#
# Verificação dos valores da classificação do acidente:
# ['Com Vítimas Fatais', 'Com Vítimas Feridas', 'Sem Vítimas']
#
# Verificação dos valores do tipo do acidente:
# ['Atropelamento de Animal', 'Atropelamento de Pedestre', 'Capotamento', 'Colisão com objeto', 'Colisão frontal', 'Colisão lateral mesmo sentido', 'Colisão lateral sentido oposto', 'Colisão transversal', 'Colisão traseira', 'Derramamento de carga', 'Engavetamento', 'Eventos atípicos', 'Incêndio', 'Queda de ocupante de veículo', 'Saída de leito carroçável', 'Tombamento']
#
# Verificação dos valores da condição metereologica:
# ['Chuva', 'Céu Claro', 'Garoa/Chuvisco', 'Granizo', 'Ignorado', 'Neve', 'Nevoeiro/Neblina', 'Nublado', 'Sol', 'Vento']
#
# Verificação dos valores da causa do acidente:
# ['Acessar a via sem observar a presença dos outros veículos', 'Acesso irregular', 'Acostamento em desnível', 'Acumulo de areia ou detritos sobre o pavimento', 'Acumulo de água sobre o pavimento', 'Acumulo de óleo sobre o pavimento', 'Afundamento ou ondulação no pavimento', 'Animais na Pista', 'Ausência de reação do condutor', 'Ausência de sinalização', 'Avarias e/ou desgaste excessivo no pneu', 'Carga excessiva e/ou mal acondicionada', 'Chuva', 'Condutor Dormindo', 'Condutor deixou de manter distância do veículo da frente', 'Condutor desrespeitou a iluminação vermelha do semáforo', 'Condutor usando celular', 'Conversão proibida', 'Curva acentuada', 'Declive acentuado', 'Deficiência do Sistema de Iluminação/Sinalização', 'Deixar de acionar o farol da motocicleta (ou similar)', 'Demais Fenômenos da natureza', 'Demais falhas mecânicas ou elétricas', 'Demais falhas na via', 'Desrespeitar a preferência no cruzamento', 'Desvio temporário', 'Entrada inopinada do pedestre', 'Estacionar ou parar em local proibido', 'Faixas de trânsito com largura insuficiente', 'Falta de acostamento', 'Falta de elemento de contenção que evite a saída do leito carroçável', 'Faróis desregulados', 'Frear bruscamente', 'Fumaça', 'Iluminação deficiente', 'Ingestão de substâncias psicoativas pelo condutor', 'Ingestão de álcool e/ou substâncias psicoativas pelo pedestre', 'Ingestão de álcool ou de substâncias psicoativas pelo pedestre', 'Ingestão de álcool pelo condutor', 'Mal súbito do condutor', 'Manobra de mudança de faixa', 'Modificação proibida', 'Neblina', 'Objeto estático sobre o leito carroçável', 'Obras na pista', 'Obstrução na via', 'Participar de racha', 'Pedestre andava na pista', 'Pedestre cruzava a pista fora da faixa', 'Pista Escorregadia', 'Pista em desnível', 'Pista esburacada', 'Problema com o freio', 'Problema na suspensão', 'Reação tardia ou ineficiente do condutor', 'Redutor de velocidade em desacordo', 'Restrição de visibilidade em curvas horizontais', 'Restrição de visibilidade em curvas verticais', 'Retorno proibido', 'Semáforo com defeito', 'Sinalização encoberta', 'Sinalização mal posicionada', 'Sistema de drenagem ineficiente', 'Trafegar com motocicleta (ou similar) entre as faixas', 'Transitar na calçada', 'Transitar na contramão', 'Transitar no acostamento', 'Ultrapassagem Indevida', 'Velocidade Incompatível', 'Área urbana sem a presença de local apropriado para a travessia de pedestres']
#
# Verificação dos valores do tipo do veículo:
# ['Automóvel', 'Bicicleta', 'Caminhonete', 'Caminhão', 'Caminhão-trator', 'Camioneta', 'Carro de mão', 'Carroça-charrete', 'Ciclomotor', 'Micro-ônibus', 'Motocicleta', 'Motoneta', 'Não Informado', 'Não se aplica', 'Outros', 'Quadriciclo', 'Reboque', 'Semireboque', 'Trator de esteira', 'Trator de rodas', 'Trator misto', 'Trem-bonde', 'Triciclo', 'Utilitário', 'Ônibus']
#
# Verificação dos valores do ano de fabricação do veículo:
# [0.0, 1900.0, 1929.0, 1946.0, 1962.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0, 2022.0]
#
# Verificação do número de valores do ano de fabricação do veículo iguais a 0:
# [2745]
#
#
# Analise do df: 2023
#
# Valores Ausentes:
# id                           0
# tipo_veiculo                 0
# marca                     4184
# ano_fabricacao_veiculo    5350
# data_inversa                 0
# dia_semana                   0
# horario                      0
# uf                           0
# br                         159
# km                         159
# municipio                    0
# causa_acidente               0
# tipo_acidente                0
# classificacao_acidente       0
# fase_dia                     0
# sentido_via                  0
# condicao_metereologica       0
# tipo_pista                   0
# tracado_via                  0
# uso_solo                     0
# pessoas                      0
# mortos                       0
# feridos                      0
# veiculos                     0
# latitude                     0
# longitude                    0
# delegacia                   18
# estado_valido                0
# dtype: int64
#
# Data e horário estão certos!
#
# Verificação dos valores dia da semana:
# ['domingo', 'quarta-feira', 'quinta-feira', 'segunda-feira', 'sexta-feira', 'sábado', 'terça-feira']
#
# Verificação dos valores fase do dia:
# ['Amanhecer', 'Anoitecer', 'Plena Noite', 'Pleno dia']
# Verificação dos valores do estado:
# Todos os estados são validos.
#
# Verificação se existe mais pessoas feridas do que pessoas numa linha:
# Não há casos onde o número de pessoas feridas é maior que o número de pessoas.
#
# Verificação se existe mais mortos do que pessoas numa linha:
# Não há casos onde o número mortos é maior que o número de pessoas.
#
# Verificação dos valores pessoas envolvidas:
# Verificação dos valores pessoas feridas:
# Verificação dos valores de mortos:
# Verificação dos valores de número de veiculos:
# Verificação se os valores de pessoas for 0 (nulo):
# Não há valores 0 em pessoas
#
# Verificação se os valores de veículo for 0 (nulo):
# Não há valores 0 em veículo
#
# Verificação dos valores do sentido da via:
# ['Crescente', 'Decrescente', 'Não Informado']
#
# Verificação dos valores do tipo da pista:
# ['Dupla', 'Múltipla', 'Simples']
#
# Verificação dos valores do uso do solo:
# ['Não', 'Sim']
#
# Verificação dos valores do tracado da via:
# ['Aclive', 'Aclive;Curva                  ', 'Aclive;Curva;Em Obras         ', 'Aclive;Curva;Interseção de Via', 'Aclive;Curva;Retorno Regulamen', 'Aclive;Curva;Rotatória        ', 'Aclive;Curva;Viaduto          ', 'Aclive;Curva;Viaduto;Retorno R', 'Aclive;Desvio Temporário      ', 'Aclive;Desvio Temporário;Curva', 'Aclive;Em Obras               ', 'Aclive;Em Obras;Curva         ', 'Aclive;Em Obras;Reta          ', 'Aclive;Interseção de Vias     ', 'Aclive;Interseção de Vias;Curv', 'Aclive;Interseção de Vias;Reta', 'Aclive;Ponte                  ', 'Aclive;Ponte;Curva            ', 'Aclive;Ponte;Curva;Viaduto    ', 'Aclive;Ponte;Reta             ', 'Aclive;Reta                   ', 'Aclive;Reta;Desvio Temporário ', 'Aclive;Reta;Desvio Temporário;', 'Aclive;Reta;Em Obras          ', 'Aclive;Reta;Interseção de Vias', 'Aclive;Reta;Ponte             ', 'Aclive;Reta;Retorno Regulament', 'Aclive;Reta;Rotatória         ', 'Aclive;Reta;Viaduto           ', 'Aclive;Retorno Regulamentado  ', 'Aclive;Retorno Regulamentado;C', 'Aclive;Retorno Regulamentado;I', 'Aclive;Retorno Regulamentado;R', 'Aclive;Retorno Regulamentado;V', 'Aclive;Rotatória              ', 'Aclive;Viaduto                ', 'Aclive;Viaduto;Curva          ', 'Aclive;Viaduto;Reta           ', 'Curva', 'Curva;Aclive                  ', 'Curva;Aclive;Em Obras         ', 'Curva;Aclive;Interseção de Via', 'Curva;Aclive;Ponte            ', 'Curva;Aclive;Retorno Regulamen', 'Curva;Aclive;Rotatória        ', 'Curva;Aclive;Viaduto          ', 'Curva;Aclive;Viaduto;Retorno R', 'Curva;Declive                 ', 'Curva;Declive;Desvio Temporári', 'Curva;Declive;Em Obras        ', 'Curva;Declive;Interseção de Vi', 'Curva;Declive;Ponte           ', 'Curva;Declive;Retorno Regulame', 'Curva;Declive;Rotatória;Inters', 'Curva;Declive;Viaduto         ', 'Curva;Desvio Temporário       ', 'Curva;Desvio Temporário;Aclive', 'Curva;Desvio Temporário;Decliv', 'Curva;Desvio Temporário;Em Obr', 'Curva;Em Obras                ', 'Curva;Em Obras;Aclive         ', 'Curva;Em Obras;Declive        ', 'Curva;Em Obras;Desvio Temporár', 'Curva;Interseção de Vias      ', 'Curva;Interseção de Vias;Acliv', 'Curva;Interseção de Vias;Decli', 'Curva;Interseção de Vias;Em Ob', 'Curva;Interseção de Vias;Ponte', 'Curva;Interseção de Vias;Retor', 'Curva;Interseção de Vias;Rotat', 'Curva;Interseção de Vias;Viadu', 'Curva;Ponte                   ', 'Curva;Ponte;Aclive            ', 'Curva;Ponte;Declive           ', 'Curva;Ponte;Interseção de Vias', 'Curva;Ponte;Viaduto           ', 'Curva;Retorno Regulamentado   ', 'Curva;Retorno Regulamentado;Ac', 'Curva;Retorno Regulamentado;De', 'Curva;Retorno Regulamentado;In', 'Curva;Retorno Regulamentado;Ro', 'Curva;Retorno Regulamentado;Vi', 'Curva;Rotatória               ', 'Curva;Rotatória;Declive       ', 'Curva;Rotatória;Declive;Viadut', 'Curva;Rotatória;Em Obras      ', 'Curva;Rotatória;Interseção de ', 'Curva;Rotatória;Retorno Regula', 'Curva;Rotatória;Viaduto       ', 'Curva;Túnel                   ', 'Curva;Túnel;Declive;Retorno Re', 'Curva;Túnel;Viaduto           ', 'Curva;Viaduto                 ', 'Curva;Viaduto;Aclive          ', 'Curva;Viaduto;Aclive;Interseçã', 'Curva;Viaduto;Declive         ', 'Curva;Viaduto;Interseção de Vi', 'Curva;Viaduto;Retorno Regulame', 'Declive', 'Declive;Curva                 ', 'Declive;Curva;Desvio Temporári', 'Declive;Curva;Em Obras        ', 'Declive;Curva;Em Obras;Desvio ', 'Declive;Curva;Interseção de Vi', 'Declive;Curva;Ponte           ', 'Declive;Curva;Retorno Regulame', 'Declive;Curva;Rotatória;Viadut', 'Declive;Curva;Túnel           ', 'Declive;Curva;Viaduto         ', 'Declive;Desvio Temporário     ', 'Declive;Desvio Temporário;Em O', 'Declive;Desvio Temporário;Reta', 'Declive;Em Obras              ', 'Declive;Em Obras;Curva        ', 'Declive;Em Obras;Desvio Tempor', 'Declive;Em Obras;Reta         ', 'Declive;Em Obras;Reta;Desvio T', 'Declive;Em Obras;Viaduto      ', 'Declive;Interseção de Vias    ', 'Declive;Interseção de Vi ...
#
# Verificação dos valores da classificação do acidente:
# ['Com Vítimas Fatais', 'Com Vítimas Feridas', 'Sem Vítimas']
#
# Verificação dos valores do tipo do acidente:
# ['Atropelamento de Animal', 'Atropelamento de Pedestre', 'Capotamento', 'Colisão com objeto', 'Colisão frontal', 'Colisão lateral mesmo sentido', 'Colisão lateral sentido oposto', 'Colisão transversal', 'Colisão traseira', 'Derramamento de carga', 'Engavetamento', 'Eventos atípicos', 'Incêndio', 'Queda de ocupante de veículo', 'Saída de leito carroçável', 'Tombamento']
#
# Verificação dos valores da condição metereologica:
# ['Chuva', 'Céu Claro', 'Garoa/Chuvisco', 'Granizo', 'Ignorado', 'Neve', 'Nevoeiro/Neblina', 'Nublado', 'Sol', 'Vento']
#
# Verificação dos valores da causa do acidente:
# ['Acessar a via sem observar a presença dos outros veículos', 'Acesso irregular', 'Acostamento em desnível', 'Acumulo de areia ou detritos sobre o pavimento', 'Acumulo de água sobre o pavimento', 'Acumulo de óleo sobre o pavimento', 'Afundamento ou ondulação no pavimento', 'Animais na Pista', 'Ausência de reação do condutor', 'Ausência de sinalização', 'Avarias e/ou desgaste excessivo no pneu', 'Carga excessiva e/ou mal acondicionada', 'Chuva', 'Condutor Dormindo', 'Condutor deixou de manter distância do veículo da frente', 'Condutor desrespeitou a iluminação vermelha do semáforo', 'Condutor usando celular', 'Conversão proibida', 'Curva acentuada', 'Declive acentuado', 'Deficiência do Sistema de Iluminação/Sinalização', 'Deixar de acionar o farol da motocicleta (ou similar)', 'Demais Fenômenos da natureza', 'Demais falhas mecânicas ou elétricas', 'Demais falhas na via', 'Desrespeitar a preferência no cruzamento', 'Desvio temporário', 'Entrada inopinada do pedestre', 'Estacionar ou parar em local proibido', 'Faixas de trânsito com largura insuficiente', 'Falta de acostamento', 'Falta de elemento de contenção que evite a saída do leito carroçável', 'Faróis desregulados', 'Frear bruscamente', 'Fumaça', 'Iluminação deficiente', 'Ingestão de substâncias psicoativas pelo condutor', 'Ingestão de álcool e/ou substâncias psicoativas pelo pedestre', 'Ingestão de álcool ou de substâncias psicoativas pelo pedestre', 'Ingestão de álcool pelo condutor', 'Mal súbito do condutor', 'Manobra de mudança de faixa', 'Modificação proibida', 'Neblina', 'Objeto estático sobre o leito carroçável', 'Obras na pista', 'Obstrução Via tentativa Assalto', 'Obstrução na via', 'Participar de racha', 'Pedestre - Ingestão de álcool/ substâncias psicoativas', 'Pedestre andava na pista', 'Pedestre cruzava a pista fora da faixa', 'Pista Escorregadia', 'Pista em desnível', 'Pista esburacada', 'Problema com o freio', 'Problema na suspensão', 'Reação tardia ou ineficiente do condutor', 'Redutor de velocidade em desacordo', 'Restrição de visibilidade em curvas horizontais', 'Restrição de visibilidade em curvas verticais', 'Retorno proibido', 'Semáforo com defeito', 'Sinalização encoberta', 'Sinalização mal posicionada', 'Sistema de drenagem ineficiente', 'Suicídio (presumido)', 'Trafegar com motocicleta (ou similar) entre as faixas', 'Transitar na calçada', 'Transitar na contramão', 'Transitar no Acostamento', 'Transtornos Mentais (exceto suicidio)', 'Ultrapassagem Indevida', 'Velocidade Incompatível', 'Área urbana sem a presença de local apropriado para a travessia de pedestres']
#
# Verificação dos valores do tipo do veículo:
# ['Automóvel', 'Bicicleta', 'Caminhonete', 'Caminhão', 'Caminhão-trator', 'Carro de mão', 'Carroça-charrete', 'Chassi-plataforma', 'Ciclomotor', 'Micro-ônibus', 'Motocicleta', 'Motoneta', 'Não Informado', 'Não se aplica', 'Outros', 'Reboque', 'Semireboque', 'Trator de esteira', 'Trator de rodas', 'Trator misto', 'Trem-bonde', 'Triciclo', 'Utilitário', 'Ônibus']
#
# Verificação dos valores do ano de fabricação do veículo:
# [0.0, 1900.0, 1955.0, 1959.0, 1961.0, 1962.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0, 2022.0, 2023.0]
#
# Verificação do número de valores do ano de fabricação do veículo iguais a 0:
# [2750]
#
#
# Analise do df: 2024
#
# Valores Ausentes:
# id                           0
# tipo_veiculo                 0
# marca                     1538
# ano_fabricacao_veiculo    1872
# data_inversa                 0
# dia_semana                   0
# horario                      0
# uf                           0
# br                          55
# km                          55
# municipio                    0
# causa_acidente               0
# tipo_acidente                0
# classificacao_acidente       0
# fase_dia                     0
# sentido_via                  0
# condicao_metereologica       0
# tipo_pista                   0
# tracado_via                  0
# uso_solo                     0
# pessoas                      0
# mortos                       0
# feridos                      0
# veiculos                     0
# latitude                     0
# longitude                    0
# delegacia                    9
# estado_valido                0
# dtype: int64
#
# Data e horário estão certos!
#
# Verificação dos valores dia da semana:
# ['domingo', 'quarta-feira', 'quinta-feira', 'segunda-feira', 'sexta-feira', 'sábado', 'terça-feira']
#
# Verificação dos valores fase do dia:
# ['Amanhecer', 'Anoitecer', 'Plena Noite', 'Pleno dia']
# Verificação dos valores do estado:
# Todos os estados são validos.
#
# Verificação se existe mais pessoas feridas do que pessoas numa linha:
# Não há casos onde o número de pessoas feridas é maior que o número de pessoas.
#
# Verificação se existe mais mortos do que pessoas numa linha:
# Não há casos onde o número mortos é maior que o número de pessoas.
#
# Verificação dos valores pessoas envolvidas:
# Verificação dos valores pessoas feridas:
# Verificação dos valores de mortos:
# Verificação dos valores de número de veiculos:
# Verificação se os valores de pessoas for 0 (nulo):
# Não há valores 0 em pessoas
#
# Verificação se os valores de veículo for 0 (nulo):
# Não há valores 0 em veículo
#
# Verificação dos valores do sentido da via:
# ['Crescente', 'Decrescente', 'Não Informado']
#
# Verificação dos valores do tipo da pista:
# ['Dupla', 'Múltipla', 'Simples']
#
# Verificação dos valores do uso do solo:
# ['Não', 'Sim']
#
# Verificação dos valores do tracado da via:
# ['Aclive', 'Aclive;Curva', 'Aclive;Curva;Em Obras', 'Aclive;Curva;Interseção de Vias', 'Aclive;Curva;Retorno Regulamentado', 'Aclive;Curva;Viaduto', 'Aclive;Em Obras', 'Aclive;Em Obras;Curva', 'Aclive;Em Obras;Interseção de Vias;Curva', 'Aclive;Em Obras;Reta', 'Aclive;Interseção de Vias', 'Aclive;Interseção de Vias;Curva', 'Aclive;Interseção de Vias;Curva;Retorno Regulamentado', 'Aclive;Interseção de Vias;Reta', 'Aclive;Interseção de Vias;Retorno Regulamentado', 'Aclive;Interseção de Vias;Rotatória;Reta', 'Aclive;Ponte;Curva', 'Aclive;Ponte;Reta', 'Aclive;Reta', 'Aclive;Reta;Em Obras', 'Aclive;Reta;Em Obras;Desvio Temporário', 'Aclive;Reta;Interseção de Vias', 'Aclive;Reta;Retorno Regulamentado;Interseção de Vias', 'Aclive;Reta;Rotatória', 'Aclive;Reta;Viaduto', 'Aclive;Retorno Regulamentado', 'Aclive;Retorno Regulamentado;Curva', 'Aclive;Rotatória', 'Aclive;Rotatória;Curva', 'Aclive;Viaduto', 'Aclive;Viaduto;Curva', 'Aclive;Viaduto;Reta', 'Curva', 'Curva;Aclive', 'Curva;Aclive;Desvio Temporário;Em Obras', 'Curva;Aclive;Em Obras', 'Curva;Aclive;Interseção de Vias', 'Curva;Aclive;Rotatória', 'Curva;Aclive;Rotatória;Interseção de Vias', 'Curva;Aclive;Viaduto', 'Curva;Declive', 'Curva;Declive;Em Obras', 'Curva;Declive;Interseção de Vias', 'Curva;Declive;Ponte', 'Curva;Declive;Retorno Regulamentado', 'Curva;Declive;Viaduto', 'Curva;Declive;Viaduto;Interseção de Vias', 'Curva;Desvio Temporário', 'Curva;Desvio Temporário;Aclive', 'Curva;Desvio Temporário;Declive', 'Curva;Em Obras', 'Curva;Em Obras;Declive', 'Curva;Em Obras;Desvio Temporário', 'Curva;Em Obras;Ponte', 'Curva;Interseção de Vias', 'Curva;Interseção de Vias;Declive', 'Curva;Interseção de Vias;Rotatória', 'Curva;Interseção de Vias;Viaduto', 'Curva;Ponte', 'Curva;Ponte;Em Obras', 'Curva;Retorno Regulamentado', 'Curva;Retorno Regulamentado;Aclive', 'Curva;Retorno Regulamentado;Declive;Em Obras', 'Curva;Retorno Regulamentado;Interseção de Vias;Declive', 'Curva;Retorno Regulamentado;Viaduto', 'Curva;Rotatória', 'Curva;Rotatória;Aclive;Interseção de Vias', 'Curva;Rotatória;Declive', 'Curva;Rotatória;Interseção de Vias', 'Curva;Viaduto', 'Curva;Viaduto;Aclive', 'Curva;Viaduto;Interseção de Vias', 'Declive', 'Declive;Curva', 'Declive;Curva;Em Obras', 'Declive;Curva;Em Obras;Desvio Temporário', 'Declive;Curva;Interseção de Vias', 'Declive;Curva;Retorno Regulamentado', 'Declive;Curva;Viaduto', 'Declive;Desvio Temporário', 'Declive;Desvio Temporário;Curva', 'Declive;Desvio Temporário;Em Obras', 'Declive;Desvio Temporário;Reta;Em Obras', 'Declive;Em Obras', 'Declive;Em Obras;Curva', 'Declive;Em Obras;Reta', 'Declive;Interseção de Vias', 'Declive;Interseção de Vias;Em Obras;Curva', 'Declive;Interseção de Vias;Reta', 'Declive;Interseção de Vias;Rotatória', 'Declive;Ponte', 'Declive;Ponte;Curva', 'Declive;Ponte;Reta', 'Declive;Reta', 'Declive;Reta;Em Obras', 'Declive;Reta;Em Obras;Viaduto', 'Declive;Reta;Interseção de Vias', 'Declive;Reta;Ponte', 'Declive;Reta;Retorno Regulamentado', 'Declive;Reta;Viaduto', 'Declive;Retorno Regulamentado', 'Declive;Retorno Regulamentado;Curva', 'Declive;Retorno Regulamentado;Interseção de Vias', 'Declive;Retorno Regulamentado;Reta', 'Declive;Retorno Regulamentado;Reta;Interseção de Vias', 'Declive;Retorno Regulamentado;Reta;Viaduto', 'Declive;Rotatória', 'Declive;Rotatória;Curva', 'Declive;Rotatória;Interseção de Vias', 'Declive;Rotatória;Reta', 'Declive;Rotatória;Retorno Regulamentado;Reta;Interseção de Vias', 'Declive;Viaduto', 'Declive;Viaduto;Curva', 'Declive;Viaduto;Reta', 'Desvio Temporário', 'Desvio Temporário;Aclive;Em Obras', 'Desvio Temporário;Aclive;Reta', 'Desvio Temporário;Curva;Em Obras', 'Desvio Temporário;Declive;Curva', 'Desvio Temporário;Declive;Em Obras;Reta', 'Desvio Temporário;Em Obras', 'Desvio Temporário;Em Obras;Aclive', 'Desvio Temporário;Em Obras;Reta', 'Desvio Temporário;Em Obras;Reta;Aclive', 'Desvio Temporário;Ponte;Em Obras;Reta', 'Desvio Temporário;Ponte;Reta', 'Desvio Temporário;Reta;Declive;Em Obras', 'Desvio Temporário ...
#
# Verificação dos valores da classificação do acidente:
# ['Com Vítimas Fatais', 'Com Vítimas Feridas', 'Sem Vítimas']
#
# Verificação dos valores do tipo do acidente:
# ['Atropelamento de Animal', 'Atropelamento de Pedestre', 'Capotamento', 'Colisão com objeto', 'Colisão frontal', 'Colisão lateral mesmo sentido', 'Colisão lateral sentido oposto', 'Colisão transversal', 'Colisão traseira', 'Derramamento de carga', 'Engavetamento', 'Eventos atípicos', 'Incêndio', 'Queda de ocupante de veículo', 'Saída de leito carroçável', 'Sinistro pessoal de trânsito', 'Tombamento']
#
# Verificação dos valores da condição metereologica:
# ['Chuva', 'Céu Claro', 'Garoa/Chuvisco', 'Ignorado', 'Nevoeiro/Neblina', 'Nublado', 'Sol', 'Vento']
#
# Verificação dos valores da causa do acidente:
# ['Acessar a via sem observar a presença dos outros veículos', 'Acesso irregular', 'Acostamento em desnível', 'Acumulo de areia ou detritos sobre o pavimento', 'Acumulo de água sobre o pavimento', 'Acumulo de óleo sobre o pavimento', 'Afundamento ou ondulação no pavimento', 'Animais na Pista', 'Ausência de reação do condutor', 'Ausência de sinalização', 'Avarias e/ou desgaste excessivo no pneu', 'Carga excessiva e/ou mal acondicionada', 'Chuva', 'Condutor Dormindo', 'Condutor deixou de manter distância do veículo da frente', 'Condutor desrespeitou a iluminação vermelha do semáforo', 'Condutor usando celular', 'Conversão proibida', 'Curva acentuada', 'Declive acentuado', 'Deficiência do Sistema de Iluminação/Sinalização', 'Deixar de acionar o farol da motocicleta (ou similar)', 'Demais Fenômenos da natureza', 'Demais falhas mecânicas ou elétricas', 'Demais falhas na via', 'Desrespeitar a preferência no cruzamento', 'Desvio temporário', 'Entrada inopinada do pedestre', 'Estacionar ou parar em local proibido', 'Faixas de trânsito com largura insuficiente', 'Falta de acostamento', 'Falta de elemento de contenção que evite a saída do leito carroçável', 'Faróis desregulados', 'Frear bruscamente', 'Fumaça', 'Iluminação deficiente', 'Ingestão de substâncias psicoativas pelo condutor', 'Ingestão de álcool pelo condutor', 'Mal súbito do condutor', 'Manobra de mudança de faixa', 'Modificação proibida', 'Neblina', 'Objeto estático sobre o leito carroçável', 'Participar de racha', 'Pedestre - Ingestão de álcool/ substâncias psicoativas', 'Pedestre andava na pista', 'Pedestre cruzava a pista fora da faixa', 'Pista Escorregadia', 'Pista esburacada', 'Problema com o freio', 'Problema na suspensão', 'Reação tardia ou ineficiente do condutor', 'Restrição de visibilidade em curvas horizontais', 'Restrição de visibilidade em curvas verticais', 'Retorno proibido', 'Semáforo com defeito', 'Sinalização mal posicionada', 'Sistema de drenagem ineficiente', 'Suicídio (presumido)', 'Trafegar com motocicleta (ou similar) entre as faixas', 'Transitar na calçada', 'Transitar na contramão', 'Transitar no Acostamento', 'Transtornos Mentais (exceto suicidio)', 'Ultrapassagem Indevida', 'Velocidade Incompatível', 'Área urbana sem a presença de local apropriado para a travessia de pedestres']
#
# Verificação dos valores do tipo do veículo:
# ['Automóvel', 'Bicicleta', 'Caminhonete', 'Caminhão', 'Caminhão-trator', 'Carroça-charrete', 'Ciclomotor', 'Micro-ônibus', 'Motocicleta', 'Motoneta', 'Não Informado', 'Não se aplica', 'Outros', 'Quadriciclo', 'Reboque', 'Semireboque', 'Trator de esteira', 'Trator de rodas', 'Trem-bonde', 'Triciclo', 'Utilitário', 'Ônibus']
#
# Verificação dos valores do ano de fabricação do veículo:
# [0.0, 1900.0, 1959.0, 1964.0, 1966.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0, 2022.0, 2023.0, 2024.0]
#
# Verificação do número de valores do ano de fabricação do veículo iguais a 0:
# [1107]

# %% [markdown]
# # Verificações feitas:
#
# Valores ausentes.<br>
# Data e hórario em formato padrão e se existem.<br>
# Dia da semana em formato padrão e se existe.<br>
# Fase do dia em formato padrão e se existe.<br>
# Distribuição da fase do dia com o horário marcado.<br>
# Estados em formato padrão e se existem.<br>
# Distribuição das métricas pessoas, feridos, mortos, veículos.<br>
# Verificação de outliers das pessoas, feridos, mortos, veículos.<br>
# Verificação de acidentes com número de feridos > número de pessoas ou número de mortos > número de pessoas.<br>
# Uso solo em formato padrão.<br>
# Tipo pista em formato padrão.<br>
# Sentido via em formato padrão.<br>
# Traçado via em formato padrão.<br>
# Classificação acidente em formato padrão. <br>
# Tipo acidente em formato padrão. <br>
# Condição meteriológica em formato padrão. <br>
# Causa acidente em formato padrão. <br>
# Tipo veículo em formato padrão. <br>
# Ano de fabricação válido. <br>
#
# # Erros
#
# ## Valores da dimensão tempo
# Existem valores de fase do dia que não corresponde com horario marcado. Ex: Pleno dia as 23 horas
#
# ## Valores da dimensão local
# Valores ausentes em delegacia.
#
# ## Valores da dimensão fato
#
# Métricas da dimensão fato possui alguns outliers. Ex: Pessoas envolvidas: 70. Como cada métrica possui um número considerável de outliers, talvez não seja erro de digitação e os acidentes realmente aconteceram.
#
# ## Valores da dimensão rodovia
# Existem valores do traçado via que estão em formatos errados. Ex: "Acli", "Aclive          ".
#
# ## Valores da dimensão descritivo
# Nenhum erro encontrado.
#
# ## Valores da dimensão veículo
# Ano de fabricação com valores ausentes 0 ou null.
# Marca com valores ausentes.
